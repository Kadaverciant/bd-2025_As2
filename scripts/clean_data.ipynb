# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

def clean_campaigns(df):
    df['total_count'] = df['total_count'].astype('object')
    df['hour_limit'] = df['hour_limit'].astype('object')
    df['subject_length'] = df['subject_length'].astype('object')
    df['position'] = df['position'].astype('object')
    
    for i, row in df.iterrows():
        if not pd.isna(row['total_count']):
            df.at[i,'total_count'] = int(row['total_count'])
        if not pd.isna(row['hour_limit']):
            df.at[i,'hour_limit'] = int(row['hour_limit'])
        if not pd.isna(row['subject_length']):
            df.at[i,'subject_length'] = int(row['subject_length'])
        if not pd.isna(row['position']):
            df.at[i,'position'] = int(row['position'])
        if pd.isna(row['ab_test']):
            df.at[i,'ab_test'] = False
            
    df.to_csv("../data/campaigns_cleaned.csv", index=False)
    return df

campaigns_df = pd.read_csv("../data/campaigns.csv")
campaigns_cleaned_df = clean_campaigns(campaigns_df)
campaigns_cleaned_df
# Out:
#        id  campaign_type      channel             topic  \
# 0      63           bulk  mobile_push          sale out
# 1      64           bulk  mobile_push          sale out
# 2      78           bulk  mobile_push          sale out
# 3      79           bulk  mobile_push          sale out
# 4      89           bulk  mobile_push               NaN
# ...   ...            ...          ...               ...
# 1902  179  transactional        email   profile updated
# 1903   35  transactional        email    order reminder
# 1904   57  transactional        email    order reminder
# 1905   56  transactional        email    order reminder
# 1906  237  transactional        email  wish list status
#
#                       started_at          finished_at total_count ab_test  \
# 0     2021-04-30 07:22:36.615023  2021-04-30 07:23:41       48211   False
# 1     2021-04-30 09:02:50.817227  2021-04-30 09:04:08     1037337   False
# 2     2021-05-06 07:14:10.533318  2021-05-06 07:15:17       70080   False
# 3     2021-05-06 09:03:56.486750  2021-05-06 09:42:15      921838   False
# 4     2021-05-07 11:54:06.168664  2021-05-07 11:54:38       45503   False
# ...                          ...                  ...         ...     ...
# 1902                         NaN                  NaN         NaN   False
# 1903                         NaN                  NaN         NaN   False
# 1904                         NaN                  NaN         NaN   False
# 1905                         NaN                  NaN         NaN   False
# 1906                         NaN                  NaN         NaN   False
#
#      warmup_mode hour_limit subject_length subject_with_personalization  \
# 0          False        NaN            146                        False
# 1          False        NaN             97                        False
# 2          False        NaN            146                        False
# 3          False        NaN             97                        False
# 4          False        NaN            109                        False
# ...          ...        ...            ...                          ...
# 1902         NaN        NaN            134                        False
# 1903         NaN        NaN             88                        False
# 1904         NaN        NaN             88                        False
# 1905         NaN        NaN             88                        False
# 1906         NaN        NaN            104                        False
#
#      subject_with_deadline subject_with_emoji subject_with_bonuses  \
# 0                    False               True                False
# 1                    False               True                False
# 2                    False               True                False
# 3                    False               True                False
# 4                     True               True                False
# ...                    ...                ...                  ...
# 1902                 False              False                False
# 1903                 False              False                False
# 1904                 False              False                False
# 1905                 False              False                False
# 1906                 False               True                False
#
#      subject_with_discount subject_with_saleout is_test position
# 0                    False                False     NaN      NaN
# 1                    False                False     NaN      NaN
# 2                    False                False     NaN      NaN
# 3                    False                False     NaN      NaN
# 4                    False                False     NaN      NaN
# ...                    ...                  ...     ...      ...
# 1902                 False                False     NaN      NaN
# 1903                 False                False     NaN      NaN
# 1904                 False                False     NaN      NaN
# 1905                 False                False     NaN      NaN
# 1906                 False                False     NaN      NaN
#
# [1907 rows x 19 columns]

# %%
messages_df = pd.read_csv("../data/messages.csv")
clients_df = pd.read_csv("../data/client_first_purchase_date.csv")
available_users = clients_df["client_id"].values.tolist()

messages_cleaned_df = messages_df[messages_df["client_id"].isin(available_users)]
messages_cleaned_df.to_csv("../data/messages_cleaned.csv", index=False)
# Out:
# C:\Users\Kiaver\AppData\Local\Temp\ipykernel_13036\3764109495.py:1: DtypeWarning: Columns (7,8,16,17,21,23,25,27,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   messages_df = pd.read_csv("../data/messages.csv")

# %%
display(campaigns_cleaned_df.dtypes)
# Out:
# id                                int64
# campaign_type                    object
# channel                          object
# topic                            object
# started_at                       object
# finished_at                      object
# total_count                      object
# ab_test                          object
# warmup_mode                      object
# hour_limit                      float64
# subject_length                  float64
# subject_with_personalization     object
# subject_with_deadline            object
# subject_with_emoji               object
# subject_with_bonuses             object
# subject_with_discount            object
# subject_with_saleout             object
# is_test                          object
# position                        float64
# dtype: object

# %%
campaigns_cleaned_df['total_count'] = campaigns_cleaned_df['total_count'].astype('object')
for i, row in campaigns_cleaned_df.iterrows():
    if not pd.isna(row['total_count']):
        campaigns_cleaned_df.at[i,'total_count'] = int(row['total_count'])
    if pd.isna(row['ab_test']):
        campaigns_cleaned_df.at[i,'ab_test'] = False

# %%
campaigns_cleaned_df
# Out:
#        id  campaign_type      channel             topic  \
# 0      63           bulk  mobile_push          sale out
# 1      64           bulk  mobile_push          sale out
# 2      78           bulk  mobile_push          sale out
# 3      79           bulk  mobile_push          sale out
# 4      89           bulk  mobile_push               NaN
# ...   ...            ...          ...               ...
# 1902  179  transactional        email   profile updated
# 1903   35  transactional        email    order reminder
# 1904   57  transactional        email    order reminder
# 1905   56  transactional        email    order reminder
# 1906  237  transactional        email  wish list status
#
#                       started_at          finished_at total_count ab_test  \
# 0     2021-04-30 07:22:36.615023  2021-04-30 07:23:41       48211   False
# 1     2021-04-30 09:02:50.817227  2021-04-30 09:04:08     1037337   False
# 2     2021-05-06 07:14:10.533318  2021-05-06 07:15:17       70080   False
# 3     2021-05-06 09:03:56.486750  2021-05-06 09:42:15      921838   False
# 4     2021-05-07 11:54:06.168664  2021-05-07 11:54:38       45503   False
# ...                          ...                  ...         ...     ...
# 1902                         NaN                  NaN         NaN   False
# 1903                         NaN                  NaN         NaN   False
# 1904                         NaN                  NaN         NaN   False
# 1905                         NaN                  NaN         NaN   False
# 1906                         NaN                  NaN         NaN   False
#
#      warmup_mode  hour_limit  subject_length subject_with_personalization  \
# 0          False         NaN           146.0                        False
# 1          False         NaN            97.0                        False
# 2          False         NaN           146.0                        False
# 3          False         NaN            97.0                        False
# 4          False         NaN           109.0                        False
# ...          ...         ...             ...                          ...
# 1902         NaN         NaN           134.0                        False
# 1903         NaN         NaN            88.0                        False
# 1904         NaN         NaN            88.0                        False
# 1905         NaN         NaN            88.0                        False
# 1906         NaN         NaN           104.0                        False
#
#      subject_with_deadline subject_with_emoji subject_with_bonuses  \
# 0                    False               True                False
# 1                    False               True                False
# 2                    False               True                False
# 3                    False               True                False
# 4                     True               True                False
# ...                    ...                ...                  ...
# 1902                 False              False                False
# 1903                 False              False                False
# 1904                 False              False                False
# 1905                 False              False                False
# 1906                 False               True                False
#
#      subject_with_discount subject_with_saleout is_test  position
# 0                    False                False     NaN       NaN
# 1                    False                False     NaN       NaN
# 2                    False                False     NaN       NaN
# 3                    False                False     NaN       NaN
# 4                    False                False     NaN       NaN
# ...                    ...                  ...     ...       ...
# 1902                 False                False     NaN       NaN
# 1903                 False                False     NaN       NaN
# 1904                 False                False     NaN       NaN
# 1905                 False                False     NaN       NaN
# 1906                 False                False     NaN       NaN
#
# [1907 rows x 19 columns]
